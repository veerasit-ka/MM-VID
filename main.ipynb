# %%
import os
from moviepy.editor import VideoFileClip
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import scenedetect
from scenedetect import VideoManager, SceneManager
from scenedetect.detectors import ContentDetector
import whisperx
import openai
from PIL import Image
import numpy as np
from langchain.chat_models import AzureChatOpenAI
from langchain.schema.messages import HumanMessage, AIMessage
import ast
# Out:
# torchvision is not available - cannot save figures

# %%
api_base = 'https://westus3-gpt-4o.openai.azure.com/' # your endpoint should look like the following https://YOUR_RESOURCE_NAME.openai.azure.com/
api_key = "e735d250c3424ed794c472b5ff8f38a0"
deployment_name = "gpt-4o"
api_version = "2024-02-01"

client = AzureChatOpenAI(
    api_key=api_key,  
    api_version=api_version,
    azure_endpoint=api_base,
    deployment_name=deployment_name,
    max_tokens=1024,
    temperature=0
)

# %%
# client = OpenAI(api_key="your openai api here")

# Step 1: Scene Detection
def scene_detection(video_path):
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(ContentDetector())
    video_manager.set_downscale_factor()
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)
    scene_list = scene_manager.get_scene_list()
    video_manager.release()
    return scene_list

# Step 2: Split Video into Multiple Clips
def split_video(video_path, scene_list, output_dir):
    clip_paths = []
    for i, scene in enumerate(scene_list):
        start, end = scene[0].get_seconds(), scene[1].get_seconds()
        clip_path = os.path.join(output_dir, f"clip_{i+1}.mp4")
        ffmpeg_extract_subclip(video_path, start, end, targetname=clip_path)
        clip_paths.append(clip_path)
    return clip_paths

# Step 3: Speech Recognition using WhisperX
def speech_recognition(video_path):
    try:
        model = whisperx.load_model("large", device='cpu')
        result = model.transcribe(video_path)
        return result["text"]
    except Exception as e:
        print(f"Error during ASR: {e}")
        return "No transcription."

# Step 4: Generate Clip-Level Video Descriptions
def generate_clip_descriptions(clip_paths, scenes):
    descriptions = []
    for clip_path, scene in zip(clip_paths, scenes):
        clip = VideoFileClip(clip_path)
        frames = sample_frames(clip, 10)
        images = [Image.fromarray(frame) for frame in frames]
        # Convert frames to base64 for OpenAI Image API
        image_files = [convert_to_base64(image) for image in images]
        content = []
        prompt = f"""You are an expert in understanding scene transitions based on visual features in a video.
                  For the given sequence of images per timestamp, identify different scenes in the video.
                  Generate pure audio description for each scene with time ranges.
                  The output should be a list of audio descriptions for each scene.
                  {scene}"""

        for image_file in image_files:
            content.append({
                            "type": "image_url",
                            "image_url": {"url": f"data:image/jpeg;base64,{image_file}"},
                        })
        response = client.invoke(
            [AIMessage(content=prompt),
             HumanMessage(content=content)]
        )

        descriptions.append(response.content)
        
    return "".join(descriptions)

# Helper function to sample frames
def sample_frames(video, num_frames):
    total_frames = int(video.fps * video.duration)
    frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    frames = [video.get_frame(i / video.fps) for i in frame_indices]
    return frames

# Helper function to convert PIL image to base64
def convert_to_base64(image):
    from io import BytesIO
    import base64

    buffered = BytesIO()
    image.save(buffered, format="JPEG")
    return base64.b64encode(buffered.getvalue()).decode("utf-8")

# Step 5: Generate a Coherent Script using GPT-4
def generate_script(clip_descriptions):
    prompt = (
        "You are an expert at understanding audio descriptions of different scenes in a video. "
        "Generate full audio description of each scene with non-overlapping time ranges. "
        "Keep as many scenes as possible covering all time ranges. "
        "Use character names wherever possible in the audio descriptions. "
        "Keep the audio description for each time range within one short sentence.\n\n"
    )
    prompt += "\n\n".join(clip_descriptions)
    response = client.chat_completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        max_tokens=1000,
    )
    return response.choices[0].message.content

# Example usage
if __name__ == "__main__":
    video_path = r"D:\MM-VID\Y2meta.app-Arcane Season 2 _ Official Teaser Trailer-(720p).mp4"
    output_dir = "clips"
    os.makedirs(output_dir, exist_ok=True)
    
    # Step 1: Scene Detection
    scenes = scene_detection(video_path)
    print("Detected scenes:", scenes)

    # Step 2: Split Video into Multiple Clips
    clip_paths = split_video(video_path, scenes, output_dir)
    print("Video clips created:", clip_paths)

    # Step 3: Speech Recognition using WhisperX
    transcript = speech_recognition(video_path)
    print("Transcript:", transcript)
# Out:
# VideoManager is deprecated and will be removed.
# Detected scenes: [(00:00:00.000 [frame=0, fps=24.000], 00:00:02.958 [frame=71, fps=24.000]), (00:00:02.958 [frame=71, fps=24.000], 00:00:06.458 [frame=155, fps=24.000]), (00:00:06.458 [frame=155, fps=24.000], 00:00:10.000 [frame=240, fps=24.000]), (00:00:10.000 [frame=240, fps=24.000], 00:00:12.292 [frame=295, fps=24.000]), (00:00:12.292 [frame=295, fps=24.000], 00:00:13.667 [frame=328, fps=24.000]), (00:00:13.667 [frame=328, fps=24.000], 00:00:15.958 [frame=383, fps=24.000]), (00:00:15.958 [frame=383, fps=24.000], 00:00:17.208 [frame=413, fps=24.000]), (00:00:17.208 [frame=413, fps=24.000], 00:00:18.083 [frame=434, fps=24.000]), (00:00:18.083 [frame=434, fps=24.000], 00:00:20.750 [frame=498, fps=24.000]), (00:00:20.750 [frame=498, fps=24.000], 00:00:21.958 [frame=527, fps=24.000]), (00:00:21.958 [frame=527, fps=24.000], 00:00:23.500 [frame=564, fps=24.000]), (00:00:23.500 [frame=564, fps=24.000], 00:00:24.417 [frame=586, fps=24.000]), (00:00:24.417 [frame=586, fps=24.000], 00:00:26.875 [frame=645, fps=24.000]), (00:00:26.875 [frame=645, fps=24.000], 00:00:29.167 [frame=700, fps=24.000]), (00:00:29.167 [frame=700, fps=24.000], 00:00:30.375 [frame=729, fps=24.000]), (00:00:30.375 [frame=729, fps=24.000], 00:00:32.042 [frame=769, fps=24.000]), (00:00:32.042 [frame=769, fps=24.000], 00:00:33.000 [frame=792, fps=24.000]), (00:00:33.000 [frame=792, fps=24.000], 00:00:34.833 [frame=836, fps=24.000]), (00:00:34.833 [frame=836, fps=24.000], 00:00:36.083 [frame=866, fps=24.000]), (00:00:36.083 [frame=866, fps=24.000], 00:00:37.042 [frame=889, fps=24.000]), (00:00:37.042 [frame=889, fps=24.000], 00:00:39.042 [frame=937, fps=24.000]), (00:00:39.042 [frame=937, fps=24.000], 00:00:39.750 [frame=954, fps=24.000]), (00:00:39.750 [frame=954, fps=24.000], 00:00:40.417 [frame=970, fps=24.000]), (00:00:40.417 [frame=970, fps=24.000], 00:00:41.500 [frame=996, fps=24.000]), (00:00:41.500 [frame=996, fps=24.000], 00:00:43.167 [frame=1036, fps=24.000]), (00:00:43.167 [frame=1036, fps=24.000], 00:00:44.208 [frame=1061, fps=24.000]), (00:00:44.208 [frame=1061, fps=24.000], 00:00:45.292 [frame=1087, fps=24.000]), (00:00:45.292 [frame=1087, fps=24.000], 00:00:46.000 [frame=1104, fps=24.000]), (00:00:46.000 [frame=1104, fps=24.000], 00:00:46.833 [frame=1124, fps=24.000]), (00:00:46.833 [frame=1124, fps=24.000], 00:00:48.042 [frame=1153, fps=24.000]), (00:00:48.042 [frame=1153, fps=24.000], 00:00:48.875 [frame=1173, fps=24.000]), (00:00:48.875 [frame=1173, fps=24.000], 00:00:49.708 [frame=1193, fps=24.000]), (00:00:49.708 [frame=1193, fps=24.000], 00:00:51.917 [frame=1246, fps=24.000]), (00:00:51.917 [frame=1246, fps=24.000], 00:00:53.125 [frame=1275, fps=24.000]), (00:00:53.125 [frame=1275, fps=24.000], 00:00:54.542 [frame=1309, fps=24.000]), (00:00:54.542 [frame=1309, fps=24.000], 00:00:56.208 [frame=1349, fps=24.000]), (00:00:56.208 [frame=1349, fps=24.000], 00:00:57.208 [frame=1373, fps=24.000]), (00:00:57.208 [frame=1373, fps=24.000], 00:00:58.042 [frame=1393, fps=24.000]), (00:00:58.042 [frame=1393, fps=24.000], 00:00:59.208 [frame=1421, fps=24.000]), (00:00:59.208 [frame=1421, fps=24.000], 00:01:00.125 [frame=1443, fps=24.000]), (00:01:00.125 [frame=1443, fps=24.000], 00:01:01.167 [frame=1468, fps=24.000]), (00:01:01.167 [frame=1468, fps=24.000], 00:01:01.917 [frame=1486, fps=24.000]), (00:01:01.917 [frame=1486, fps=24.000], 00:01:02.708 [frame=1505, fps=24.000]), (00:01:02.708 [frame=1505, fps=24.000], 00:01:03.708 [frame=1529, fps=24.000]), (00:01:03.708 [frame=1529, fps=24.000], 00:01:04.625 [frame=1551, fps=24.000]), (00:01:04.625 [frame=1551, fps=24.000], 00:01:05.292 [frame=1567, fps=24.000]), (00:01:05.292 [frame=1567, fps=24.000], 00:01:07.500 [frame=1620, fps=24.000]), (00:01:07.500 [frame=1620, fps=24.000], 00:01:08.292 [frame=1639, fps=24.000]), (00:01:08.292 [frame=1639, fps=24.000], 00:01:11.083 [frame=1706, fps=24.000]), (00:01:11.083 [frame=1706, fps=24.000], 00:01:16.042 [frame=1825, fps=24.000]), (00:01:16.042 [frame=1825, fps=24.0 ...
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Video clips created: ['clips\\clip_1.mp4', 'clips\\clip_2.mp4', 'clips\\clip_3.mp4', 'clips\\clip_4.mp4', 'clips\\clip_5.mp4', 'clips\\clip_6.mp4', 'clips\\clip_7.mp4', 'clips\\clip_8.mp4', 'clips\\clip_9.mp4', 'clips\\clip_10.mp4', 'clips\\clip_11.mp4', 'clips\\clip_12.mp4', 'clips\\clip_13.mp4', 'clips\\clip_14.mp4', 'clips\\clip_15.mp4', 'clips\\clip_16.mp4', 'clips\\clip_17.mp4', 'clips\\clip_18.mp4', 'clips\\clip_19.mp4', 'clips\\clip_20.mp4', 'clips\\clip_21.mp4', 'clips\\clip_22.mp4', 'clips\\clip_23.mp4', 'clips\\clip_24.mp4', 'clips\\clip_25.mp4', 'clips\\clip_26.mp4', 'clips\\clip_27.mp4', 'clips\\clip_28.mp4', 'clips\\clip_29.mp4', 'clips\\clip_30.mp4', 'clips\\clip_31.mp4', 'clips\\clip_32.mp4', 'clips\\clip_33.mp4', 'clips\\clip_34.mp4', 'clips\\clip_35.mp4', 'clips\\clip_36.mp4', 'clips\\clip_37.mp4', 'clips\\clip_38.mp4', 'clips\\clip_39.mp4', 'clips\\clip_40.mp4', 'clips\\clip_41.mp4', 'clips\\clip_42.mp4', 'clips\\clip_43.mp4', 'clips\\clip_44.mp4', 'clips\\clip_45.mp4', 'clips\\clip_46.mp4', 'clips\\clip_47.mp4', 'clips\\clip_48.mp4', 'clips\\clip_49.mp4', 'clips\\clip_50.mp4', 'clips\\clip_51.mp4', 'clips\\clip_52.mp4', 'clips\\clip_53.mp4', 'clips\\clip_54.mp4', 'clips\\clip_55.mp4', 'clips\\clip_56.mp4', 'clips\\clip_57.mp4', 'clips\\clip_58.mp4', 'clips\\clip_59.mp4', 'clips\\clip_60.mp4']
# Error during ASR: Requested float16 compute type, but the target device or backend do not support efficient float16 computation.
# Transcript: No transcription.

# %%
descriptions = []
for clip_path, scene in zip(clip_paths, scenes):
    clip = VideoFileClip(clip_path)
    frames = sample_frames(clip, 10)
    images = [Image.fromarray(frame) for frame in frames]
    # Convert frames to base64 for OpenAI Image API
    image_files = [convert_to_base64(image) for image in images]
    content = []
    prompt = f"""You are an expert in understanding scene transitions based on visual features in a video.
                For the given sequence of images per timestamp, identify different scenes in the video.
                Generate pure audio description for each scene with time ranges.
                The output should be a list of audio descriptions for each scene.
                {scene}"""

    for image_file in image_files:
        content.append({
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{image_file}"},
                    })
    # response = client.invoke(
    #     [AIMessage(content=prompt),
    #         HumanMessage(content=content)]
    # )

    # descriptions.append(response.content)

# %%
# Step 4: Generate Clip Descriptions
clip_descriptions = generate_clip_descriptions(clip_paths, scenes)
print("Clip Descriptions:", clip_descriptions)

# clip_descriptions = clip_descriptions + f'\n\n ASR:{transcript}'

# # Step 5: Generate a Coherent Script
# script = generate_script(clip_descriptions)
# print("Generated Script:", script)
# Out:
# Clip Descriptions: 1. **Scene 1: 00:00:00.000 - 00:00:00.500**
#    - Audio Description: "The screen is completely black."
#
# 2. **Scene 2: 00:00:00.500 - 00:00:02.958**
#    - Audio Description: "A dark, foggy environment slowly becomes visible. Two figures, possibly humanoid, emerge from the mist, illuminated by faint blue lights. The scene is eerie and mysterious, with the figures moving slowly through the fog."1. **Scene 1 (00:00:02.958 - 00:00:03.958)**
#    - Audio Description: "The screen is completely black."
#
# 2. **Scene 2 (00:00:03.958 - 00:00:06.458)**
#    - Audio Description: "A dimly lit room with a broken, elevated platform in the center. The platform has a small, damaged structure on it, resembling a monument or a piece of machinery. The room appears to be in disrepair, with cracks and debris visible."1. **Scene 1 (00:00:06.458 - 00:00:09.000)**
#    - Audio Description: "A close-up of armored boots stepping over a large, futuristic weapon with glowing green lights. The background is dark and filled with smoke and purple hues."
#
# 2. **Scene 2 (00:00:09.000 - 00:00:10.000)**
#    - Audio Description: "A person with red hair and a red jacket turns around quickly, looking alert. The background is dimly lit with industrial elements and gears."1. **00:00:10.000 - 00:00:11.000**
#    - Audio Description: "The scene is dark, with very little visible detail."
#
# 2. **00:00:11.000 - 00:00:12.292**
#    - Audio Description: "A close-up of a person's face, partially obscured, as they hold a golden mask. The person appears to be examining the mask closely."1. **00:00:12.292 - 00:00:13.667**: A character in ornate armor is seen putting on a golden mask, covering their face completely. The background is blurred, focusing on the character's action.1. **Scene 1 (00:00:13.667 - 00:00:15.958):**
#    - A large, futuristic ship is flying through dense, dark clouds illuminated by a reddish glow. The ship's lights and the surrounding clouds create a dramatic and intense atmosphere. The scene captures the ship's movement as it navigates through the ominous sky.1. **00:00:15.958 - 00:00:17.208**
#    - **Audio Description:** The scene takes place in a dimly lit room with a red hue. A character with red hair is seen moving through a crowd. The atmosphere is tense, and the character appears to be in a hurry or on a mission. The background is filled with other characters, suggesting a busy or chaotic environment.1. **00:00:17.208 - 00:00:18.083**
#    - **Audio Description:** A line of armored soldiers stands at attention, their faces obscured by metallic helmets. They raise their right arms in a synchronized salute, their movements precise and uniform. In the background, other figures, possibly officers, observe the scene. The setting appears to be a formal or ceremonial event, with the soldiers displaying discipline and unity.1. **00:00:18.083 - 00:00:20.750**
#    - **Audio Description:** The scene begins with a black screen, indicating a transition or a pause. It then shifts to a close-up view of two individuals in uniform, suggesting a formal or official setting. The focus is on their upper bodies, highlighting their attire and insignia. The background is dark, emphasizing the characters in the foreground.1. **00:00:20.750 - 00:00:21.958**
#    - A close-up view of a golden, intricately designed weapon with a glowing blue core. The weapon is being held and adjusted, with the blue core pulsing and emitting light.
#
# 2. **00:00:21.958 - 00:00:23.000**
#    - The camera angle shifts to show the weapon from a different perspective, focusing on the scope and the barrel. The weapon is being aimed, and the scope's lens reflects light as it moves into position.1. **00:00:21.958 - 00:00:22.500**
#    - Audio Description: "A close-up view of a golden, ornate rifle with a large scope. The rifle is being held by someone in a blue and gold uniform."
#
# 2. **00:00:22.500 - 00:00:23.000**
#    - Audio Description: "The camera zooms out slightly, revealing more of the rifle and the person holding it. The person is wearing a blue and gold uniform with intricate details."
#
# 3. **00:00:23.000 - 00:00:23.500**
#    - Audio Description: "The camera continues to zoom out, showing the person holding the rifle in a more complete view. The person is wearing a blue and gold uniform with a white shirt underneath, and black gloves. The rifle is prominently displayed in their hands."1. **Time Range: 00:00:23.500 - 00:00:24.417**
#    - **Audio Description:** A close-up view of a mechanical, intricate lock mechanism with glowing blue lights. The lock appears to be in the process of unlocking, with parts moving and shifting slightly. The scene is detailed with metallic textures and a futuristic design.1. **Scene 1: 00:00:24.417 - 00:00:26.875**
#    - Audio Description: "The screen is completely black, with no visible elements or movement."
#
# 2. **Scene 2: 00:00:26.875 - 00:00:30.000**
#    - Audio Description: "A dimly lit scene begins to emerge, revealing a close-up of a belt with intricate designs and a metallic emblem. The belt is part of a uniform or costume, and the scene gradually becomes clearer."1. **Scene 1 (00:00:26.875 - 00:00:29.167):**
#    - A character with red hair and a blue and gold outfit is shown against a dark background. The character's face is blurred, and they appear to be looking forward. The lighting is dim, creating a serious and focused atmosphere.1. **00:00:29.167 - 00:00:30.375**
#    - Audio Description: "Text on screen reads 'This November' in glowing golden letters against a dark background."
#
# 2. **00:00:30.375 - onwards**
#    - Audio Description: "A dynamic scene with fast-moving, colorful lights and blurred motion, suggesting action or energy."1. **00:00:30.375 - 00:00:30.875**
#    - Audio Description: "A blur of bright, fiery colors with flashes of green and yellow, suggesting a fast-paced or intense action scene."
#
# 2. **00:00:30.875 - 00:00:31.375**
#    - Audio Description: "A flying vehicle with green glowing lights hovers over a dark, industrial landscape."
#
# 3. **00:00:31.375 - 00:00:31.875**
#    - Audio Description: "The flying vehicle continues to hover, revealing more of the dark, industrial surroundings below."
#
# 4. **00:00:31.875 - 00:00:32.042**
#    - Audio Description: "The vehicle's green lights create streaks as it moves rapidly, with the industrial landscape still visible below."
#
# 5. **00:00:32.042 - 00:00:32.542**
#    - Audio Description: "A scene transition to a red-tinted environment with structural elements, possibly indicating a different location or a change in the atmosphere."
#
# 6. **00:00:32.542 - 00:00:33.042**
#    - Audio Description: "A character or object, glowing with vibrant colors, descends rapidly amidst the red-tinted environment, suggesting a dynamic action sequence."
#
# 7. **00:00:33.042 - 00:00:33.542**
#    - Audio Description: "The character or object continues to descend, with the vibrant colors and rapid movement emphasizing the intensity of the scene."1. **Scene 1 (00:00:32.042 - 00:00:33.000):**
#    - A character in a futuristic suit with a glowing purple visor is in mid-air, surrounded by shards of glass and vibrant green and red lights. The character appears to be in an action sequence, possibly attacking or dodging something. The background is dark with hints of structural elements, suggesting an indoor or enclosed environment.1. **00:00:33.000 - 00:00:34.833**
#    - **Audio Description:** A close-up of a character's face, showing a determined expression. The character is wearing armor with orange and blue accents. The scene is dimly lit with a reddish hue.
#
# 2. **00:00:34.833 - 00:00:36.000**
#    - **Audio Description:** The camera shifts slightly, focusing on the character's shoulder and part of their face, which is partially obscured. The background remains dimly lit with a reddish hue.
#
# 3. **00:00:36.000 - 00:00:37.000**
#    - **Audio Description:** The scene transitions to a close-up of a large, armored figure with a glowing purple visor. Shards of glass or debris are flying around, indicating a chaotic environment.
#
# 4. **00:00:37.000 - 00:00:38.000**
#    - **Audio Description:** The armored figure is seen in a dynamic pose, possibly in the middle of an action sequence. The background is dark with red and green lighting effects.
#
# 5. **00:00:38.000 - 00:00:39.000**
#    - **Audio Description:** The armored figure is now in a more aggressive stance, with green energy or light emanating from their arm. Another character is visible in the background, seemingly in a defensive position.
#
# 6. **00:00:39.000 - 00:00:40.000**
#    - **Audio Description:** The scene shows the armored figure lunging forward with green energy trailing behind. The background character appears to be bracing for impact.
#
# 7. **00:00:40.000 - 00:00:41.000**
#    - **Audio Description:** The armored figure is in mid-air, attacking another character who is defending with a weapon. The background is filled with red and orange lighting, suggesting an intense battle.
#
# 8. **00:00:41.000 - 00:00:42.000**
#    - **Audio Description:** The scene transitions to a title card with the text "WITNESS THE FINAL CHAPTER" in bold, glowing letters against a dark background.1. **00:00:34.833 - 00:00:36.083**
#    - "Witness the final chapter" text appears on the screen with a glowing effect.
#
# 2. **00:00:36.083 - onwards**
#    - A close-up shot of a character's hands holding a weapon, with other characters blurred in the background.1. **00:00:36.083 - 00:00:37.042**
#    - A close-up view of a character's hands as they handle a weapon, possibly a rifle, with intricate designs. The background shows other characters in similar attire, suggesting a military or ceremonial setting. The character appears to be preparing or inspecting the weapon.1. **00:00:37.042 - 00:00:39.042**
#    - **Audio Description:** A character dressed in a dark blue uniform with gold accents and a white hat is shown in a close-up shot. The character's face is obscured, but the detailed gold armor and a red gem on the chest are visible. The background is dark, emphasizing the character's attire.1. **00:00:39.042 - 00:00:39.750**
#    - Audio Description: "A group of armored figures stands in a dimly lit, red-hued room. They are positioned in a circular formation, facing outward, with their shields raised."1. **00:00:39.750 - 00:00:40.417**
#    - **Audio Description:** A group of armored soldiers with shields and gas masks march forward in a dimly lit room with red lights. The scene is tense and foreboding, with the sound of heavy footsteps and the clanking of metal.1. **00:00:40.417 - 00:00:41.500**
#    - **Audio Description:** "The scene shows a wall covered with wanted posters. The posters prominently feature a character with blue hair, labeled 'Jinx,' and the word 'Wanted' below. The background is splattered with green paint and other graffiti."1. **00:00:41.500 - 00:00:42.000**
#    - Audio Description: "A dark, foggy scene with low visibility."
#
# 2. **00:00:42.000 - 00:00:42.500**
#    - Audio Description: "A close-up of a boot stepping onto a surface, causing it to crack."
#
# 3. **00:00:42.500 - 00:00:43.167**
#    - Audio Description: "A person in armor jumps forward, with colorful lights and robotic creatures in the background."1. **00:00:43.167 - 00:00:44.208**
#    - **Audio Description:** A close-up view of a character with red hair and armor, with a robotic figure in the background. The scene is dimly lit, suggesting a tense or dramatic moment. The robotic figure has glowing green and purple lights, adding to the futuristic atmosphere.1. **00:00:44.208 - 00:00:45.292**
#    - **Audio Description:** A character with red hair and a mechanical arm is seen in a dark, futuristic environment. The character's arm is equipped with glowing blue and purple lights, and there are small floating mechanical devices around them. The character appears to be in a ready stance, possibly preparing for action.1. **00:00:45.292 - 00:00:46.000**
#    - Scene Description: The scene begins with a view of a crowded area, possibly an arena or a battleground, with characters preparing for action. The atmosphere is tense, and the lighting is dim, suggesting an impending conflict.
#
# 2. **00:00:46.000 - 00:00:46.500**
#    - Scene Description: The scene transitions to an intense battle sequence. Bright, colorful energy blasts and dynamic movements dominate the frame. Characters are engaged in combat, with powerful attacks creating vibrant explosions of light and energy.
#
# 3. **00:00:46.500 - 00:00:47.000**
#    - Scene Description: The battle continues with more energy blasts and explosions. The screen is filled with bright pink and blue hues, indicating the use of powerful abilities or weapons. The action is fast-paced and chaotic, with characters moving rapidly.
#
# 4. **00:00:47.000 - 00:00:47.500**
#    - Scene Description: The scene maintains its high intensity with continuous explosions and energy blasts. The colors remain vibrant, and the action is relentless. Characters are still engaged in fierce combat, with no signs of slowing down.
#
# 5. **00:00:47.500 - 00:00:48.000**
#    - Scene Description: The scene reaches a climax with a massive explosion of pink and blue energy. The screen is almost entirely filled with the bright colors, indicating a significant impact or attack. The action is at its peak, with the outcome of the battle hanging in the balance.1. **00:00:46.000 - 00:00:46.833**
#    - Scene Description: "A group of armored soldiers is seen aiming their rifles, ready for action. The background is filled with a hazy, golden light, suggesting a battlefield or a tense standoff."
#
# 2. **00:00:46.833 - onwards**
#    - Scene Description: "A bald figure stands facing away from the camera, with two armored soldiers aiming their weapons at him from a distance. The scene is bathed in a dramatic, golden light, creating a sense of tension and confrontation."1. **00:00:46.833 - 00:00:48.042**
#    - **Audio Description:** A tense standoff scene unfolds in a dimly lit room. A bald figure stands in the foreground, facing two armored soldiers who are aiming their weapons at him. The light from behind casts a dramatic glow, highlighting the tension in the air. The figure raises his hands, holding small objects, possibly weapons, as if preparing for a confrontation. The soldiers remain poised, ready to react.1. **00:00:48.042 - 00:00:48.875**
#    - A person is seen holding and aiming a large, futuristic weapon that emits a pinkish glow. The scene is enveloped in a thick, smoky atmosphere, creating a sense of tension and anticipation.
#
# 2. **00:00:48.875 - End**
#    - The scene transitions to a group of people facing a large, mechanical entity with glowing purple lights. The environment is filled with a reddish haze, suggesting a dramatic and possibly dangerous situation.1. **00:00:48.875 - 00:00:49.708**
#    - A large, glowing, mechanical figure looms over a group of people. The scene is filled with smoke and a sense of tension as the figure's lights illuminate the surroundings. The group appears to be in a defensive stance, facing the mechanical figure.
#
# 2. **00:00:49.708 - 00:00:50.708**
#    - The mechanical figure raises one of its arms, revealing a large, glowing blade. The group of people remains in the foreground, seemingly preparing for an imminent confrontation. The atmosphere is charged with anticipation and danger.1. **00:00:49.708 - 00:00:50.500**
#    - Audio Description: "A chaotic scene with multiple characters in a dimly lit, red-hued environment. The atmosphere is tense and filled with action."
#
# 2. **00:00:50.500 - 00:00:51.000**
#    - Audio Description: "A close-up of a character's intense eyes, showing determination and focus."
#
# 3. **00:00:51.000 - 00:00:51.917**
#    - Audio Description: "A steampunk-themed character with mechanical enhancements, surrounded by other characters in a dark, industrial setting. The scene is filled with tension and anticipation."
#
# 4. **00:00:51.917 - 00:00:52.500**
#    - Audio Description: "A wide shot of a grand, ornate structure with intricate designs, surrounded by several characters. The environment is mystical and otherworldly, with a sense of awe and wonder."1. **00:00:51.917 - 00:00:53.125**
#    - **Audio Description**: "A group of silhouetted figures stands in a misty, dimly lit room. They face a large, ornate, circular structure that glows with a golden light. The structure is intricately designed with swirling patterns and is surrounded by various colorful lights and mechanical elements. The atmosphere is mysterious and otherworldly."1. **00:00:53.125 - 00:00:54.542**
#    - A hand is shown, illuminated by a red light, with fingers spread open.
#
# 2. **00:00:54.542 - 00:00:55.000**
#    - The hand begins to close into a fist.
#
# 3. **00:00:55.000 - 00:00:55.500**
#    - The hand is now fully clenched into a fist.
#
# 4. **00:00:55.500 - 00:00:56.000**
#    - A weapon, possibly a sword or spear, is seen moving past the clenched fist.
#
# 5. **00:00:56.000 - 00:00:56.500**
#    - The weapon continues to move past the fist, creating a sense of motion and tension.1. **00:00:54.542 - 00:00:55.208**
#    - Audio Description: "A creature with a grotesque face and sharp teeth charges down a narrow alleyway, its eyes wide with aggression. The background is filled with industrial pipes and dim lighting."
#
# 2. **00:00:55.208 - 00:00:55.875**
#    - Audio Description: "The creature continues its charge, its face contorted in a snarl. Sparks fly as it scrapes against the wall, adding to the chaotic scene."
#
# 3. **00:00:55.875 - 00:00:56.208**
#    - Audio Description: "The creature leaps into the air, brandishing sharp, mechanical claws. Its eyes are filled with fury as it prepares to attack."
#
# 4. **00:00:56.208 - 00:00:56.875**
#    - Audio Description: "A person holding a large, glowing weapon aims at the creature. The weapon is intricate, with bright, colorful lights emanating from it."
#
# 5. **00:00:56.875 - 00:00:57.542**
#    - Audio Description: "A close-up of the weapon as it is activated, emitting a bright, pink energy. The person wielding it is partially visible, focused on the creature."
#
# 6. **00:00:57.542 - 00:00:58.208**
#    - Audio Description: "The weapon's energy intensifies, creating a vivid, pink glow. The scene is filled with tension as the person prepares to fire at the charging creature."1. **00:00:56.208 - 00:00:57.208**
#    - **Audio Description:** A character with a mechanical arm engages in a fast-paced combat sequence, swinging their arm with glowing, colorful energy. The scene is dynamic and intense, with rapid movements and bright, neon-like effects.
#
# 2. **00:00:57.208 - 00:00:58.208**
#    - **Audio Description:** The scene transitions to a bright, white explosion with purple hues, indicating a powerful energy release. The explosion radiates outward, creating a dramatic visual effect.
#
# 3. **00:00:58.208 - 00:00:59.208**
#    - **Audio Description:** The camera zooms out to reveal a top-down view of the explosion's epicenter. Multiple beams of light shoot out in different directions, illuminating the surrounding area. The scene is filled with energy and chaos, with characters and objects being affected by the powerful blast.1. **00:00:57.208 - 00:00:58.042**
#    - **Audio Description:** A character with white dreadlocks and a brown scarf is standing in a dimly lit, industrial-looking environment. The character is wearing a green jacket with brown straps and metallic buttons. The background appears to be a dark tunnel or corridor. The character remains stationary, with slight movements in their posture.1. **00:00:58.042 - 00:00:59.208**
#    - **Audio Description:** A powerful figure stands in the center, holding a large, dark, and ethereal banner above their head. Blue, mystical energy emanates from the figure, creating intricate patterns in the air. Surrounding the central figure are several other characters, seemingly in awe or reverence, with their faces illuminated by the same blue energy.
#
# 2. **00:00:59.208 - onwards**
#    - **Audio Description:** The scene transitions to a bustling, futuristic cityscape. The environment is filled with tall, industrial buildings adorned with lights and various structures. People move about in the foreground, suggesting a lively and active urban setting. The atmosphere is dense, with a sense of depth and complexity in the architecture and the activities of the inhabitants.1. **00:00:59.208 - 00:01:00.125**
#    - Scene Description: A bustling, futuristic cityscape with tall buildings and a large gate in the background. People are walking around, and a character in the foreground is holding a device.
#
# 2. **00:01:00.125 - 00:01:01.000**
#    - Scene Description: The scene brightens significantly as the gate opens, revealing a bright light from behind it. The people in the scene appear to be reacting to the light.
#
# 3. **00:01:01.000 - 00:01:02.000**
#    - Scene Description: A large, bright explosion with pink and purple hues occurs behind the gate, causing the people to react and move away.
#
# 4. **00:01:02.000 - 00:01:03.000**
#    - Scene Description: The explosion continues, with bright pink and purple clouds expanding and filling the scene. The people are still reacting to the explosion.
#
# 5. **00:01:03.000 - 00:01:04.000**
#    - Scene Description: The explosion starts to subside, but the pink and purple clouds remain prominent. The people are still in the scene, reacting to the aftermath.
#
# 6. **00:01:04.000 - 00:01:05.000**
#    - Scene Description: The scene shows the aftermath of the explosion, with the pink and purple clouds still present but starting to dissipate. The people are cautiously observing the situation.
#
# 7. **00:01:05.000 - 00:01:06.000**
#    - Scene Description: The pink and purple clouds continue to dissipate, and the scene starts to return to normal. The people are still present, observing the aftermath of the explosion.
#
# 8. **00:01:06.000 - 00:01:07.000**
#    - Scene Description: The scene shows the final stages of the explosion's aftermath, with the pink and purple clouds almost completely gone. The people are still present, cautiously observing the situation.1. **Scene 1 (00:01:00.125 - 00:01:01.167):**
#    - A hooded figure stands amidst a mystical, ethereal environment filled with swirling, colorful lights and fog. The atmosphere is mysterious and otherworldly, with a sense of magic and intrigue. The figure remains mostly still, shrouded in shadows and illuminated by the ambient glow.1. **00:01:01.167 - 00:01:01.917**
#    - **Audio Description:** A character with red hair and goggles is shown in a close-up shot. The background is a worn, blue wall with patches of rust. The character appears to be in a contemplative or serious mood.
#
# 2. **00:01:01.917 - 00:01:02.167**
#    - **Audio Description:** The scene transitions to a darker, blue-lit environment. The focus is on a different character or object, partially obscured, suggesting a shift in location or focus.1. **Time Range: 00:01:01.917 - 00:01:02.708**
#    - A close-up view of a character with a white beard and blue eyes, partially obscured by a hood. The character's face becomes more visible as the scene progresses, revealing a focused and intense expression.1. **00:01:02.708 - 00:01:03.708**
#    - Scene Description: The scene opens with a dark, red-hued mist filling the screen, creating an ominous and intense atmosphere.
#
# 2. **00:01:03.708 - 00:01:04.708**
#    - Scene Description: Sparks and fiery embers fly through the air, suggesting a scene of destruction or battle.
#
# 3. **00:01:04.708 - 00:01:05.708**
#    - Scene Description: The scene reveals more details of the chaotic environment, with shadows and shapes moving amidst the red mist and embers.
#
# 4. **00:01:05.708 - 00:01:06.708**
#    - Scene Description: A closer view shows a figure or object lying on the ground, partially obscured by the red mist and surrounded by the glowing embers.
#
# 5. **00:01:06.708 - 00:01:07.708**
#    - Scene Description: The scene remains focused on the figure or object on the ground, with the red mist and embers continuing to create a sense of tension and foreboding.1. **Scene 1: 00:01:03.708 - 00:01:04.625**
#    - Description: A dark, ominous figure with glowing red eyes emerges from a smoky, red-lit environment. The figure's eyes are the most prominent feature, piercing through the darkness.
#
# 2. **Scene 2: 00:01:04.625 - 00:01:05.542**
#    - Description: The dark figure with glowing red eyes becomes more defined, revealing a large, monstrous shape. The red lighting and smoke continue to create a menacing atmosphere.
#
# 3. **Scene 3: 00:01:05.542 - 00:01:06.458**
#    - Description: The monstrous figure's eyes glow even brighter, and its full form starts to become clearer. The red lighting intensifies, highlighting the creature's menacing presence.
#
# 4. **Scene 4: 00:01:06.458 - 00:01:07.375**
#    - Description: The scene transitions to a close-up of a person holding a futuristic weapon. The weapon is detailed and metallic, with the person's gloved hands gripping it tightly. The background is dark, suggesting a tense or dangerous situation.1. **Time Range: 00:01:04.625 - 00:01:05.292**
#    - **Audio Description:** A person is holding a futuristic rifle, with gloved hands gripping the weapon tightly. The scene is dimly lit, suggesting a tense or stealthy situation. The person is partially obscured by a wall or barrier, indicating they might be in a hiding or aiming position. The rifle has a sleek, metallic design with intricate details and a scope on top.1. **Scene 1: 00:01:05.292 - 00:01:07.500**
#    - Audio Description: "The screen is completely black, indicating a transition or a pause between scenes."
#
# 2. **Scene 2: 00:01:07.500 - onwards**
#    - Audio Description: "A close-up shot of a character's neck and shoulder, with red hair partially visible. The character appears to be wearing a dark blue outfit with white accents."1. **00:01:07.500 - 00:01:08.292**
#    - A close-up view of a mechanical device or apparatus, with a focus on a circular, glass-like component. The scene remains static, with slight changes in lighting and reflections on the glass surface. The device appears to be intricate, with metallic parts and a central, illuminated section.
#
# 2. **00:01:08.292 - 00:01:08.500**
#    - The scene transitions to a close-up of a hand interacting with the mechanical device. The hand is pressing or manipulating a part of the device, indicating some form of activation or adjustment. The focus is on the hand and the specific part of the device being touched.1. **00:01:08.292 - 00:01:09.000**
#    - A close-up of a finger pressing a button on a mechanical device.
#
# 2. **00:01:09.000 - 00:01:10.000**
#    - The finger continues to press the button, causing a reaction in the device.
#
# 3. **00:01:10.000 - 00:01:11.083**
#    - A sudden burst of blue energy and light, with a character or object being enveloped in the energy.
#
# 4. **00:01:11.083 - 00:01:12.000**
#    - The scene transitions to a view of the character or object surrounded by a circular pattern of glowing blue symbols.
#
# 5. **00:01:12.000 - 00:01:13.000**
#    - The character or object is seen moving through a tunnel of blue energy, with the circular pattern of symbols still visible.
#
# 6. **00:01:13.000 - 00:01:14.000**
#    - The character or object continues to move through the tunnel, with the blue energy swirling around them.
#
# 7. **00:01:14.000 - 00:01:15.000**
#    - The scene focuses on the character or object as they move deeper into the tunnel, with the blue energy forming a spiral pattern.
#
# 8. **00:01:15.000 - 00:01:16.000**
#    - The blue energy forms a star-like pattern as the character or object continues to move through the tunnel.
#
# 9. **00:01:16.000 - 00:01:17.000**
#    - The star-like pattern of blue energy continues to swirl around the character or object as they move through the tunnel.1. **00:01:11.083 - 00:01:12.000**
#    - Audio Description: "A bright, glowing yellow light fills the screen."
#
# 2. **00:01:12.000 - 00:01:16.042**
#    - Audio Description: "The title 'ARCANE' appears in large, illuminated letters, followed by 'LEAGUE OF LEGENDS' in smaller text below it, all set against a dark background."1. **00:01:16.042 - 00:01:17.000**
#    - A close-up of a character with red hair and a dark outfit, looking to the side.
#
# 2. **00:01:17.000 - 00:01:18.000**
#    - The same character, slightly turning their head, revealing more of their face and headgear.
#
# 3. **00:01:18.000 - 00:01:19.000**
#    - A wide shot of a large, dark room with tall pillars. The pillars are decorated with glowing, colorful graffiti.
#
# 4. **00:01:19.000 - 00:01:20.000**
#    - A closer view of the same room, focusing on the glowing graffiti on the pillars.
#
# 5. **00:01:20.000 - 00:01:20.875**
#    - A character with red hair and armor is looking up at another character standing on a rock, with glowing graffiti in the background.Based on the provided sequence of images, it appears that the video is entirely black during the given timestamps. This suggests that the scene is either a fade to black, a blackout, or a transition between scenes.
#
# Here is the audio description for the scene:
#
# 1. **00:01:20.875 - 00:01:21.833**: "The screen is completely black, indicating a possible transition or fade-out between scenes."1. **Scene 1 (00:01:21.833 - 00:01:22.750):**
#    - A close-up view of a mechanical or robotic hand with intricate details and glowing blue lights. The hand appears to be moving slightly, showcasing its mechanical components and design.1. **Scene 1 (00:01:22.750 - 00:01:23.625):**
#    - A character with blue hair and a weapon stands in a dimly lit area with colorful graffiti on the walls. The character is preparing to fire the weapon, which emits a bright pink light.
#
# 2. **Scene 2 (00:01:23.625 - 00:01:24.000):**
#    - The character fires the weapon, producing a powerful pink laser beam that illuminates the surroundings. The beam is directed towards an unseen target, creating a dramatic and intense visual effect.1. **00:01:23.625 - 00:01:24.583**
#    - A character with blue hair and a glowing pink weapon is in a dynamic action pose, seemingly in the middle of a battle. The background is dark with colorful graffiti-like art.
#
# 2. **00:01:24.583 - 00:01:25.000**
#    - The blue-haired character is now crouched, aiming the glowing pink weapon at an opponent who is mid-air, with a mechanical arm extended. The background remains dark with vibrant graffiti.
#
# 3. **00:01:25.000 - 00:01:25.500**
#    - The scene continues with the blue-haired character aiming at the airborne opponent. The opponent's face is blurred, and the mechanical arm is more visible. The background remains consistent.
#
# 4. **00:01:25.500 - 00:01:26.000**
#    - The scene darkens slightly, but the blue-haired character and the airborne opponent are still visible in their respective positions. The background graffiti is less prominent due to the dimming light.
#
# 5. **00:01:26.000 - 00:01:26.500**
#    - The scene continues to darken, with the blue-haired character and the airborne opponent becoming less visible. The background is now mostly dark, with faint outlines of the characters and graffiti.
#
# 6. **00:01:26.500 - 00:01:27.000**
#    - The scene is now very dark, with only the faintest outlines of the characters and background visible. The action seems to be pausing or transitioning to another scene.1. **00:01:24.583 - 00:01:25.333**
#    - **Audio Description:** Two characters are facing each other in a close-up shot. One character has blue hair and the other has red hair. The background is a soft blue, suggesting an intense or significant moment between them.1. **00:01:25.333 - 00:01:25.750**
#    - Audio Description: "A dark screen with a faint red gradient on the left side."
#
# 2. **00:01:25.750 - 00:01:26.083**
#    - Audio Description: "A dark screen with a red gradient on the left and a blue gradient on the right."
#
# 3. **00:01:26.083 - 00:01:26.417**
#    - Audio Description: "A dark screen with multiple vertical gradients in red, purple, and blue."
#
# 4. **00:01:26.417 - 00:01:26.583**
#    - Audio Description: "A dark screen with multiple vertical gradients in red, orange, purple, and blue."1. **00:01:26.583 - 00:01:27.250**: A series of vertical, colorful light streaks appear on a black background, gradually forming a recognizable shape. The colors transition from red on the left to blue on the right, creating a dynamic and vibrant visual effect.1. **00:01:27.250 - 00:01:29.208**
#    - Audio Description: "A red 'N' logo appears on a black background, with colorful light streaks moving vertically on either side of the logo."1. **00:01:29.208 - 00:01:30.000**
#    - Audio Description: "The screen displays a red 'N' logo on a black background, indicating the Netflix logo."
#
# 2. **00:01:30.000 - 00:01:31.333**
#    - Audio Description: "The screen transitions to a black background with white text at the bottom, displaying copyright information for Riot Games, Inc. and Arcane League of Legends."
